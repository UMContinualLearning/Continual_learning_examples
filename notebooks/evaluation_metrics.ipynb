# %% [markdown]
# # Evaluation

# %%
# !pip install avalanche-lib
# Out:
# Requirement already satisfied: avalanche-lib in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: matplotlib in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (3.4.3)
# Requirement already satisfied: torchmetrics in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (0.9.3)
# Requirement already satisfied: gputil in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/GPUtil-1.4.0-py3.7.egg (from avalanche-lib) (1.4.0)
# Requirement already satisfied: scikit-learn in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (0.24.2)
# Requirement already satisfied: psutil in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (5.8.0)
# Requirement already satisfied: pytorchcv in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/pytorchcv-0.0.67-py3.7.egg (from avalanche-lib) (0.0.67)
# Requirement already satisfied: gdown in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/gdown-4.4.0-py3.7.egg (from avalanche-lib) (4.4.0)
# Requirement already satisfied: wandb in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/wandb-0.12.11-py3.7.egg (from avalanche-lib) (0.12.11)
# Requirement already satisfied: quadprog in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (0.1.6)
# Requirement already satisfied: typing-extensions in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (3.10.0.2)
# Requirement already satisfied: torch in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (1.7.0+cpu)
# Requirement already satisfied: numpy in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (1.20.3)
# Requirement already satisfied: torchvision in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (0.8.1)
# Requirement already satisfied: tqdm in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (4.62.3)
# Requirement already satisfied: setuptools<=59.5.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (58.0.4)
# Requirement already satisfied: tensorboard>=1.15 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from avalanche-lib) (1.15.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (0.16.1)
# Requirement already satisfied: absl-py>=0.4 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (0.15.0)
# Requirement already satisfied: six>=1.10.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (1.16.0)
# Requirement already satisfied: grpcio>=1.6.3 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (1.38.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (3.17.2)
# Requirement already satisfied: wheel>=0.26 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from tensorboard>=1.15->avalanche-lib) (0.37.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard>=1.15->avalanche-lib) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=1.15->avalanche-lib) (3.6.0)
# Requirement already satisfied: filelock in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from gdown->avalanche-lib) (3.3.1)
# Requirement already satisfied: requests[socks] in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from gdown->avalanche-lib) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from gdown->avalanche-lib) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from beautifulsoup4->gdown->avalanche-lib) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from matplotlib->avalanche-lib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from matplotlib->avalanche-lib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from matplotlib->avalanche-lib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from matplotlib->avalanche-lib) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from matplotlib->avalanche-lib) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from requests[socks]->gdown->avalanche-lib) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from requests[socks]->gdown->avalanche-lib) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from requests[socks]->gdown->avalanche-lib) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from requests[socks]->gdown->avalanche-lib) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from requests[socks]->gdown->avalanche-lib) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from scikit-learn->avalanche-lib) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from scikit-learn->avalanche-lib) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from scikit-learn->avalanche-lib) (1.5.3)
# Requirement already satisfied: dataclasses in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from torch->avalanche-lib) (0.6)
# Requirement already satisfied: future in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from torch->avalanche-lib) (0.18.2)
# Requirement already satisfied: packaging in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from torchmetrics->avalanche-lib) (21.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from wandb->avalanche-lib) (8.0.3)
# Requirement already satisfied: GitPython>=1.0.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/GitPython-3.1.27-py3.7.egg (from wandb->avalanche-lib) (3.1.27)
# Requirement already satisfied: PyYAML in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from wandb->avalanche-lib) (6.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/docker_pycreds-0.4.0-py3.7.egg (from wandb->avalanche-lib) (0.4.0)
# Requirement already satisfied: pathtools in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/pathtools-0.1.2-py3.7.egg (from wandb->avalanche-lib) (0.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/promise-2.3-py3.7.egg (from wandb->avalanche-lib) (2.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/sentry_sdk-1.5.7-py3.7.egg (from wandb->avalanche-lib) (1.5.7)
# Requirement already satisfied: setproctitle in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/setproctitle-1.2.2-py3.7-linux-x86_64.egg (from wandb->avalanche-lib) (1.2.2)
# Requirement already satisfied: shortuuid>=0.5.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/shortuuid-1.0.8-py3.7.egg (from wandb->avalanche-lib) (1.0.8)
# Requirement already satisfied: yaspin>=1.0.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/yaspin-2.1.0-py3.7.egg (from wandb->avalanche-lib) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/gitdb-4.0.9-py3.7.egg (from GitPython>=1.0.0->wandb->avalanche-lib) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages/smmap-5.0.0-py3.7.egg (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->avalanche-lib) (5.0.0)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /home/alex/anaconda3/envs/avalanche-env/lib/python3.7/site-packages (from yaspin>=1.0.0->wandb->avalanche-lib) (1.1.0)

# %% [markdown]
# ## 📈 The Evaluation Module
#
#
#
# The `evaluation` module is quite straightforward: it offers all the basic functionalities to evaluate and keep track of a continual learning experiment.
#
# This is mostly done through the **Metrics**: a set of classes which implement the main continual learning metrics computation like A_ccuracy_, F_orgetting_, M_emory Usage_, R_unning Times_, etc. At the moment, in _Avalanche_ we offer a number of pre-implemented metrics you can use for your own experiments. We made sure to include all the major accuracy-based metrics but also the ones related to computation and memory.
#
# Each metric comes with a standalone class and a set of plugin classes aimed at emitting metric values on specific moments during training and evaluation.
#
# #### Standalone metric
#
# As an example, the standalone `Accuracy` class can be used to monitor the average accuracy over a stream of `<input,target>` pairs. The class provides an `update` method to update the current average accuracy, a `result` method to print the current average accuracy and a `reset` method to set the current average accuracy to zero. The call to `result`does not change the metric state.
# The `Accuracy` metric requires the `task_labels` parameter, which specifies which task is associated with the current patterns. The metric returns a dictionary mapping task labels to accuracy values.

# %%
import torch
from avalanche.evaluation.metrics import Accuracy

task_labels = 0  # we will work with a single task
# create an instance of the standalone Accuracy metric
# initial accuracy is 0 for each task
acc_metric = Accuracy()
print("Initial Accuracy: ", acc_metric.result()) #  output {}

# two consecutive metric updates
real_y = torch.tensor([1, 2]).long()
predicted_y = torch.tensor([1, 0]).float()
acc_metric.update(real_y, predicted_y, task_labels)
acc = acc_metric.result()
print("Average Accuracy: ", acc) # output 0.5 on task 0
predicted_y = torch.tensor([1,2]).float()
acc_metric.update(real_y, predicted_y, task_labels)
acc = acc_metric.result()
print("Average Accuracy: ", acc) # output 0.75 on task 0

# reset accuracy
acc_metric.reset()
print("After reset: ", acc_metric.result()) # output {}
# Out:
# Initial Accuracy:  {}
# Average Accuracy:  {0: 0.5}
# Average Accuracy:  {0: 0.75}
# After reset:  {}

# %% [markdown]
# #### Plugin metric
#
# If you want to integrate the available metrics automatically in the training and evaluation flow, you can use plugin metrics, like `EpochAccuracy` which logs the accuracy after each training epoch, or `ExperienceAccuracy` which logs the accuracy after each evaluation experience. Each of these metrics emits a **curve** composed by its values at different points in time \(e.g. on different training epochs\).  In order to simplify the use of these metrics, we provided utility functions with which you can create different plugin metrics in one shot. The results of these functions can be passed as parameters directly to the `EvaluationPlugin`\(see below\).
#
# {% hint style="info" %}
# We recommend to use the helper functions when creating plugin metrics.
# {% endhint %}

# %%
from avalanche.evaluation.metrics import accuracy_metrics, \
    loss_metrics, forgetting_metrics, bwt_metrics,\
    confusion_matrix_metrics, cpu_usage_metrics, \
    disk_usage_metrics, gpu_usage_metrics, MAC_metrics, \
    ram_usage_metrics, timing_metrics

# you may pass the result to the EvaluationPlugin
metrics = accuracy_metrics(epoch=True, experience=True)

# https://avalanche-api.continualai.org/en/latest/evaluation.html

# %% [markdown]
# ## 📐Evaluation Plugin
#
# The **Evaluation Plugin** is the object in charge of configuring and controlling the evaluation procedure. This object can be passed to a Strategy as a "special" plugin through the evaluator attribute.
#
# The Evaluation Plugin accepts as inputs the plugin metrics you want to track. In addition, you can add one or more loggers to print the metrics in different ways \(on file, on standard output, on Tensorboard...\).
#
# It is also recommended to pass to the Evaluation Plugin the benchmark instance used in the experiment. This allows the plugin to check for consistency during metrics computation. For example, the Evaluation Plugin checks that the `strategy.eval` calls are performed on the same stream or sub-stream. Otherwise, same metric could refer to different portions of the stream.
# These checks can be configured to raise errors (stopping computation) or only warnings.

# %%
from torch.nn import CrossEntropyLoss
from torch.optim import SGD
from avalanche.benchmarks.classic import SplitMNIST
from avalanche.evaluation.metrics import forgetting_metrics, \
accuracy_metrics, loss_metrics, timing_metrics, cpu_usage_metrics, \
confusion_matrix_metrics, disk_usage_metrics
from avalanche.models import SimpleMLP
from avalanche.logging import InteractiveLogger
from avalanche.training.plugins import EvaluationPlugin
from avalanche.training import Naive

# CHOOSE A BENCHMARK
benchmark = SplitMNIST(n_experiences=5)

# CHOOSE A MODEL
model = SimpleMLP(num_classes=benchmark.n_classes)

# DEFINE THE EVALUATION PLUGIN
# The evaluation plugin manages the metrics computation.
# It takes as argument a list of metrics, collectes their results and returns
# them to the strategy it is attached to.
eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True),
    forgetting_metrics(experience=True, stream=True),
    cpu_usage_metrics(experience=True),
    confusion_matrix_metrics(num_classes=benchmark.n_classes, save_image=False, stream=True),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loggers=[InteractiveLogger()],
    benchmark=benchmark,
    strict_checks=False
)

# CREATE THE STRATEGY INSTANCE (NAIVE)
cl_strategy = Naive(
    model,
    optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9), # choose an optimizer
    criterion = CrossEntropyLoss(), # choose a loss function
    train_mb_size = 500, 
    train_epochs = 3, 
    eval_mb_size = 100,
    evaluator = eval_plugin
)

# TRAINING LOOP
print('Starting experiment...')
results = []
for experience in benchmark.train_stream:
    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(benchmark.test_stream))
# Out:
# Starting experiment...
# -- >> Start of training phase << --
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  8.00it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.1944
# 	Loss_MB/train_phase/train_stream/Task000 = 0.3849
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.0010
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6921
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9016
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.81it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2557
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1733
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.0734
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9326
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9548
# 100%|███████████████████████████████████████████| 24/24 [00:02<00:00,  8.09it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1751
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1719
# 	Time_Epoch/train_phase/train_stream/Task000 = 2.9676
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9461
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9441
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 35.06it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 124.9052
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1240
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9658
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 19/19 [00:00<00:00, 34.90it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 123.2393
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 6.8738
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 33.54it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 117.7746
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 6.6754
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 35.99it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 121.1554
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 6.4846
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 34.25it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 123.1992
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.5374
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[  0,   0, 450,   0,   0,   0, 530,   0,   0,   0],
#         [  0,   0, 954,   0,   0,   0, 181,   0,   0,   0],
#         [  0,   0, 988,   0,   0,   0,  44,   0,   0,   0],
#         [  0,   0, 868,   0,   0,   0, 142,   0,   0,   0],
#         [  0,   0, 294,   0,   0,   0, 688,   0,   0,   0],
#         [  0,   0, 458,   0,   0,   0, 434,   0,   0,   0],
#         [  0,   0,  24,   0,   0,   0, 934,   0,   0,   0],
#         [  0,   0, 796,   0,   0,   0, 232,   0,   0,   0],
#         [  0,   0, 831,   0,   0,   0, 143,   0,   0,   0],
#         [  0,   0, 424,   0,   0,   0, 585,   0,   0,   0]])
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 369.7793
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.1246
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1922
# -- >> Start of training phase << --
# 100%|███████████████████████████████████████████| 23/23 [00:02<00:00,  8.30it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5653
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6289
# 	Time_Epoch/train_phase/train_stream/Task000 = 2.7720
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3572
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.7941
# 100%|███████████████████████████████████████████| 23/23 [00:02<00:00,  8.21it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.4271
# 	Loss_MB/train_phase/train_stream/Task000 = 0.3184
# 	Time_Epoch/train_phase/train_stream/Task000 = 2.8002
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8935
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9191
# 100%|███████████████████████████████████████████| 23/23 [00:02<00:00,  8.25it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2774
# 	Loss_MB/train_phase/train_stream/Task000 = 0.2150
# 	Time_Epoch/train_phase/train_stream/Task000 = 2.7900
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9234
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9522
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 33.23it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 126.8551
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9658
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 5.7953
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 19/19 [00:00<00:00, 34.20it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 124.5634
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.2111
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9502
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 33.17it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 123.3167
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 6.9331
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 34.50it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 126.6106
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 7.1667
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 35.09it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 126.2891
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 6.1846
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[  0,   0,   0,   0,   0, 938,   0,   0,  42,   0],
#         [  0,   0,   0,   0,   0, 204,   0,   0, 931,   0],
#         [  0,   0,   0,   0,   0,  59,   0,   0, 973,   0],
#         [  0,   0,   0,   0,   0, 593,   0,   0, 417,   0],
#         [  0,   0,   0,   0,   0, 296,   0,   0, 686,   0],
#         [  0,   0,   0,   0,   0, 847,   0,   0,  45,   0],
#         [  0,   0,   0,   0,   0, 474,   0,   0, 484,   0],
#         [  0,   0,   0,   0,   0, 497,   0,   0, 531,   0],
#         [  0,   0,   0,   0,   0,  48,   0,   0, 926,   0],
#         [  0,   0,   0,   0,   0, 369,   0,   0, 640,   0]])
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 369.7793
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.3369
# 	StreamForgetting/eval_phase/test_stream = 0.9658
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1773
# -- >> Start of training phase << --
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.88it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7219
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6140
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.0454
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3863
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9619
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.90it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2813
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1494
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.0380
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9707
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9725
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  6.74it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1106
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0909
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.5586
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9790
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9873
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 24.77it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 121.5068
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9658
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 5.5207
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 19/19 [00:00<00:00, 26.90it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 117.7694
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.9502
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 6.5096
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 26.01it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 118.6265
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0668
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9880
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 30.63it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 124.1607
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 6.9771
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 31.04it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 121.5576
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.6592
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[   0,    0,    0,  833,  147,    0,    0,    0,    0,    0],
#         [   0,    0,    0, 1090,   45,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  740,  292,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  989,   21,    0,    0,    0,    0,    0],
#         [   0,    0,    0,    3,  979,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  654,  238,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  174,  784,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  287,  741,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  803,  171,    0,    0,    0,    0,    0],
#         [   0,    0,    0,  111,  898,    0,    0,    0,    0,    0]])
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 369.7793
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.9385
# 	StreamForgetting/eval_phase/test_stream = 0.9580
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1968
# -- >> Start of training phase << --
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.70it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7457
# 	Loss_MB/train_phase/train_stream/Task000 = 0.6264
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.1156
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3899
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9597
# 100%|███████████████████████████████████████████| 24/24 [00:02<00:00,  8.05it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2505
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1369
# 	Time_Epoch/train_phase/train_stream/Task000 = 2.9817
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9699
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9624
# 100%|███████████████████████████████████████████| 24/24 [00:03<00:00,  7.79it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1014
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0829
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.0826
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9734
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9785
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 32.29it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 126.2533
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9658
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 4.9584
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 19/19 [00:00<00:00, 34.28it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 123.0695
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.9502
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 6.1553
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 34.09it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 123.3310
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.9880
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 5.1993
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 33.62it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 123.3586
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0602
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9869
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 33.37it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 124.5488
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.7871
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[ 973,    0,    0,    0,    0,    0,    0,    0,    0,    7],
#         [   6,    0,    0,    0,    0,    0,    0,    0,    0, 1129],
#         [ 472,    0,    0,    1,    0,    0,    0,    0,    0,  559],
#         [ 612,    0,    0,    0,    0,    0,    0,    0,    0,  398],
#         [   6,    0,    0,    0,    0,    0,    0,    0,    0,  976],
#         [ 525,    0,    0,    0,    0,    0,    0,    0,    0,  367],
#         [ 371,    0,    0,    0,    0,    0,    0,    0,    0,  587],
#         [  20,    0,    0,    0,    0,    0,    0,    0,    0, 1008],
#         [ 124,    0,    0,    0,    0,    0,    0,    0,    0,  850],
#         [  19,    0,    0,    0,    0,    0,    0,    0,    0,  990]])
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 369.7793
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.4347
# 	StreamForgetting/eval_phase/test_stream = 0.9680
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1963
# -- >> Start of training phase << --
# 100%|███████████████████████████████████████████| 27/27 [00:03<00:00,  8.04it/s]
# Epoch 0 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.5549
# 	Loss_MB/train_phase/train_stream/Task000 = 0.8855
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.3551
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3901
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.8571
# 100%|███████████████████████████████████████████| 27/27 [00:03<00:00,  8.12it/s]
# Epoch 1 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.2941
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0238
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.3262
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9641
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|███████████████████████████████████████████| 27/27 [00:03<00:00,  8.04it/s]
# Epoch 2 ended.
# 	DiskUsage_Epoch/train_phase/train_stream/Task000 = 369.7793
# 	DiskUsage_MB/train_phase/train_stream/Task000 = 369.7793
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.1015
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0868
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.3587
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9771
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 33.22it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 125.2064
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9658
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 5.0454
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 19/19 [00:00<00:00, 33.98it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 121.9155
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.9502
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 6.0496
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 30.91it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 122.5296
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.9880
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 5.4675
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 32.07it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 125.7044
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003 = 369.7793
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.8386
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 4.0611
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.1483
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 34.15it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 124.3976
# 	DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004 = 369.7793
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0679
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.9792
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[ 295,    1,    0,    0,    0,    0,    0,  684,    0,    0],
#         [   0, 1128,    0,    0,    0,    0,    0,    7,    0,    0],
#         [  24,  353,    0,    0,    0,    0,    0,  655,    0,    0],
#         [  10,  232,    0,    0,    0,    0,    0,  768,    0,    0],
#         [   0,   23,    0,    0,    0,    0,    0,  959,    0,    0],
#         [  29,   93,    0,    0,    0,    0,    0,  770,    0,    0],
#         [   2,  104,    0,    0,    0,    0,    0,  852,    0,    0],
#         [   0,   38,    0,    0,    0,    0,    0,  990,    0,    0],
#         [   0,  198,    0,    0,    0,    0,    0,  776,    0,    0],
#         [   0,   13,    0,    0,    0,    0,    0,  996,    0,    0]])
# 	DiskUsage_Stream/eval_phase/test_stream/Task000 = 369.7793
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.0445
# 	StreamForgetting/eval_phase/test_stream = 0.9356
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.2413

# %% [markdown]
# ## Implement your own metric
#
# To implement a **standalone metric**, you have to subclass `Metric` class.

# %%
from avalanche.evaluation import Metric


# a standalone metric implementation
class MyStandaloneMetric(Metric[float]):
    """
    This metric will return a `float` value
    """
    def __init__(self):
        """
        Initialize your metric here
        """
        super().__init__()
        pass

    def update(self):
        """
        Update metric value here
        """
        pass

    def result(self) -> float:
        """
        Emit the metric result here
        """
        return 0

    def reset(self):
        """
        Reset your metric here
        """
        pass

# %% [markdown]
#  To implement a **plugin metric** you have to subclass `PluginMetric` class

# %%
from avalanche.evaluation import PluginMetric
from avalanche.evaluation.metrics import Accuracy
from avalanche.evaluation.metric_results import MetricValue
from avalanche.evaluation.metric_utils import get_metric_name


class MyPluginMetric(PluginMetric[float]):
    """
    This metric will return a `float` value after
    each training epoch
    """

    def __init__(self):
        """
        Initialize the metric
        """
        super().__init__()

        self._accuracy_metric = Accuracy()

    def reset(self) -> None:
        """
        Reset the metric
        """
        self._accuracy_metric.reset()

    def result(self) -> float:
        """
        Emit the result
        """
        return self._accuracy_metric.result()

    def after_training_iteration(self, strategy: 'PluggableStrategy') -> None:
        """
        Update the accuracy metric with the current
        predictions and targets
        """
        # task labels defined for each experience
        task_labels = strategy.experience.task_labels
        if len(task_labels) > 1:
            # task labels defined for each pattern
            task_labels = strategy.mb_task_id
        else:
            task_labels = task_labels[0]
            
        self._accuracy_metric.update(strategy.mb_output, strategy.mb_y, 
                                     task_labels)

    def before_training_epoch(self, strategy: 'PluggableStrategy') -> None:
        """
        Reset the accuracy before the epoch begins
        """
        self.reset()

    def after_training_epoch(self, strategy: 'PluggableStrategy'):
        """
        Emit the result
        """
        return self._package_result(strategy)
        
        
    def _package_result(self, strategy):
        """Taken from `GenericPluginMetric`, check that class out!"""
        metric_value = self.accuracy_metric.result()
        add_exp = False
        plot_x_position = strategy.clock.train_iterations

        if isinstance(metric_value, dict):
            metrics = []
            for k, v in metric_value.items():
                metric_name = get_metric_name(
                    self, strategy, add_experience=add_exp, add_task=k)
                metrics.append(MetricValue(self, metric_name, v,
                                           plot_x_position))
            return metrics
        else:
            metric_name = get_metric_name(self, strategy,
                                          add_experience=add_exp,
                                          add_task=True)
            return [MetricValue(self, metric_name, metric_value,
                                plot_x_position)]

    def __str__(self):
        """
        Here you can specify the name of your metric
        """
        return "Top1_Acc_Epoch"

# %% [markdown]
# ## Accessing metric values

# %% [markdown]
# If you want to access all the metrics computed during training and evaluation, you have to make sure that `collect_all=True` is set when creating the `EvaluationPlugin` (default option is `True`). This option maintains an updated version of all metric results in the plugin, which can be retrieved by calling `evaluation_plugin.get_all_metrics()`. You can call this methods whenever you need the metrics.
#
# The result is a dictionary with full metric names as keys and a tuple of two lists as values. The first list stores all the `x` values recorded for that metric. Each `x` value represents the time step at which the corresponding metric value has been computed. The second list stores metric values associated to the corresponding `x` value.

# %%
eval_plugin2 = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    forgetting_metrics(experience=True, stream=True),
    timing_metrics(epoch=True),
    cpu_usage_metrics(experience=True),
    confusion_matrix_metrics(num_classes=benchmark.n_classes, save_image=False, stream=True),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    collect_all=True, # this is default value anyway
    loggers=[InteractiveLogger()],
    benchmark=benchmark
)

# since no training and evaluation has been performed, this will return an empty dict.
metric_dict = eval_plugin2.get_all_metrics()
print(metric_dict)
# Out:
# defaultdict(<function EvaluationPlugin.__init__.<locals>.<lambda> at 0x7f61b8207830>, {})

# %%
d = eval_plugin.get_all_metrics()
d['Top1_Acc_Epoch/train_phase/train_stream/Task000']
# Out:
# ([24, 48, 72, 95, 118, 141, 165, 189, 213, 237, 261, 285, 312, 339, 366],
#  [0.6920680363758841,
#   0.9325530481643651,
#   0.9461098012798922,
#   0.3571682044002839,
#   0.8934528034066714,
#   0.9234386089425124,
#   0.38628580973857846,
#   0.9706840390879479,
#   0.9789526434477575,
#   0.3899090296495957,
#   0.9699292452830188,
#   0.9733827493261455,
#   0.39009763973245176,
#   0.964096255862228,
#   0.9770892596294303])

# %% [markdown]
# Alternatively, the `train` and `eval` method of every `strategy` returns a dictionary storing, for each metric, the last value recorded for that metric. You can use these dictionaries to incrementally accumulate metrics.

# %%
print(res)
# Out:
# {'Top1_Acc_MB/train_phase/train_stream/Task000': 1.0, 'Loss_MB/train_phase/train_stream/Task000': 0.08682078123092651, 'DiskUsage_MB/train_phase/train_stream/Task000': 369.779296875, 'Top1_Acc_Epoch/train_phase/train_stream/Task000': 0.9770892596294303, 'Loss_Epoch/train_phase/train_stream/Task000': 0.10151594650179911, 'Time_Epoch/train_phase/train_stream/Task000': 3.358654104999914, 'DiskUsage_Epoch/train_phase/train_stream/Task000': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp000': 4.958388671204073, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000': 126.25332727493286, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp001': 6.155311017685509, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001': 123.06949460102864, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp002': 5.199262392090027, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002': 123.33104718321064, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003': 0.9869281045751634, 'Loss_Exp/eval_phase/test_stream/Task000/Exp003': 0.060161781923863206, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003': 123.35861281726972, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp004': 5.787115666031893, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004': 124.54876330447897, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004': 369.779296875, 'Top1_Acc_Stream/eval_phase/test_stream/Task000': 0.1963, 'Loss_Stream/eval_phase/test_stream/Task000': 4.434712746961415, 'StreamForgetting/eval_phase/test_stream': 0.9679805748872462, 'ConfusionMatrix_Stream/eval_phase/test_stream': tensor([[ 973,    0,    0,    0,    0,    0,    0,    0,    0,    7],
#         [   6,    0,    0,    0,    0,    0,    0,    0,    0, 1129],
#         [ 472,    0,    0,    1,    0,    0,    0,    0,    0,  559],
#         [ 612,    0,    0,    0,    0,    0,    0,    0,    0,  398],
#         [   6,    0,    0,    0,    0,    0,    0,    0,    0,  976],
#         [ 525,    0,    0,    0,    0,    0,    0,    0,    0,  367],
#         [ 371,    0,    0,    0,    0,    0,    0,    0,    0,  587],
#         [  20,    0,    0,    0,    0,    0,    0,    0,    0, 1008],
#         [ 124,    0,    0,    0,    0,    0,    0,    0,    0,  850],
#         [  19,    0,    0,    0,    0,    0,    0,    0,    0,  990]]), 'DiskUsage_Stream/eval_phase/test_stream/Task000': 369.779296875, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp000': 0.9658291457286432, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp001': 0.9501607717041801, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp002': 0.9879518072289156}

# %%
print(results[-1])
# Out:
# {'Top1_Acc_MB/train_phase/train_stream/Task000': 1.0, 'Loss_MB/train_phase/train_stream/Task000': 0.08682078123092651, 'DiskUsage_MB/train_phase/train_stream/Task000': 369.779296875, 'Top1_Acc_Epoch/train_phase/train_stream/Task000': 0.9770892596294303, 'Loss_Epoch/train_phase/train_stream/Task000': 0.10151594650179911, 'Time_Epoch/train_phase/train_stream/Task000': 3.358654104999914, 'DiskUsage_Epoch/train_phase/train_stream/Task000': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp000': 5.045413048423115, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000': 125.20644600699093, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp000': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp001': 6.049633934311289, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp001': 121.91549652906451, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp001': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002': 0.0, 'Loss_Exp/eval_phase/test_stream/Task000/Exp002': 5.467479656020322, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp002': 122.52956168624152, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp002': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003': 0.14831573655103067, 'Loss_Exp/eval_phase/test_stream/Task000/Exp003': 4.061117208801123, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp003': 125.70438487602316, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp003': 369.779296875, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004': 0.9791955617198336, 'Loss_Exp/eval_phase/test_stream/Task000/Exp004': 0.06789009906248229, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp004': 124.39761380340468, 'DiskUsage_Exp/eval_phase/test_stream/Task000/Exp004': 369.779296875, 'Top1_Acc_Stream/eval_phase/test_stream/Task000': 0.2413, 'Loss_Stream/eval_phase/test_stream/Task000': 4.044461677515693, 'StreamForgetting/eval_phase/test_stream': 0.9356385231714679, 'ConfusionMatrix_Stream/eval_phase/test_stream': tensor([[ 295,    1,    0,    0,    0,    0,    0,  684,    0,    0],
#         [   0, 1128,    0,    0,    0,    0,    0,    7,    0,    0],
#         [  24,  353,    0,    0,    0,    0,    0,  655,    0,    0],
#         [  10,  232,    0,    0,    0,    0,    0,  768,    0,    0],
#         [   0,   23,    0,    0,    0,    0,    0,  959,    0,    0],
#         [  29,   93,    0,    0,    0,    0,    0,  770,    0,    0],
#         [   2,  104,    0,    0,    0,    0,    0,  852,    0,    0],
#         [   0,   38,    0,    0,    0,    0,    0,  990,    0,    0],
#         [   0,  198,    0,    0,    0,    0,    0,  776,    0,    0],
#         [   0,   13,    0,    0,    0,    0,    0,  996,    0,    0]]), 'DiskUsage_Stream/eval_phase/test_stream/Task000': 369.779296875, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp000': 0.9658291457286432, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp001': 0.9501607717041801, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp002': 0.9879518072289156, 'ExperienceForgetting/eval_phase/test_stream/Task000/Exp003': 0.8386123680241327}
